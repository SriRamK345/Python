# %% [markdown]
# <a href="https://colab.research.google.com/github/SriRamK345/Python/blob/main/Py_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Square martix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Array addition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## "#" problem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## max and min of array

# %%
arr = [1,3]
print(min(arr))
# Out:
# 1

# %%
s= 0
arr = [1,3]
n=len(arr)
for i in range(n):
    s+= arr[i] # 1, 3
print(s)
# Out:
# 4

# %%
mini = 9999
maxi = 0
arry = [1,2,3]

for i in range(len(arr)):
    mini = min(mini, arr[i])
    maxi = max(maxi, arr[i])
print(mini, maxi)
# Out:
# 1 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Count Max in array

# %%
arr = [1,3,4,5,6,5]

print(arr.count(max(arr)))
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Time AM to PM

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Grading Student

# %%
print(73%5)
# Out:
# 3

# %%
print(67%5)
# Out:
# 2

# %%
grades = [73,67,38,33]

res = []
for i in grades:
  if i >= 38:
    mod5 = i%5 #3 #2

    if mod5 >= 3:
      i = i + (5-mod5) #73+2
  res.append(i)

print(res)
# Out:
# [75, 67, 40, 33]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
